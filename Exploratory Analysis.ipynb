# %%
weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["Issue Date"] = df["Issue Date"].astype("datetime64[ms]")
df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

df.groupby(["issue_weekday"])["Summons Number"].count().sort_values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       1 weekday_names = {
#       2     0: "Monday",
#       3     1: "Tuesday",
#    (...)
#       8     6: "Sunday",
#       9 }
# ---> 11 df["Issue Date"] = df["Issue Date"].astype("datetime64[ms]")
#      12 df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)
#      14 df.groupby(["issue_weekday"])["Summons Number"].count().sort_values()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# Load the Excel file
file_path = 'D:\PYTHON DATA\OpenDataPortalMonthlyIssuance20160920.xlsx'
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\HP\AppData\Local\Temp\ipykernel_22132\25975792.py:4: SyntaxWarning: invalid escape sequence '\P'
#   file_path = 'D:\PYTHON DATA\OpenDataPortalMonthlyIssuance20160920.xlsx'
#    Source Column Name               Description/Comment
# 0      SUMMONS-NUMBER  UNIQUE IDENTIFIER OF SUMMONS
# 1            PLATE ID          REGISTERED PLATE ID
# 2  REGISTRATION STATE   STATE OF PLATE REGISTRATION
# 3          PLATE TYPE                TYPE OF PLATE
# 4          ISSUE-DATE                  ISSUE DATE

# %%
# Display summary statistics
print(df.describe())

# Check for missing values
print(df.isnull().sum())

# Get information about the DataFrame
print(df.info())
# Out:
#        Source Column Name            Description/Comment
# count                  43                             43
# unique                 43                             41
# top        SUMMONS-NUMBER  GEOGRAPHICAL STREET CODE
# freq                    1                              3
# Source Column Name     0
# Description/Comment    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Source Column Name   43 non-null     object
#  1   Description/Comment  43 non-null     object
# dtypes: object(2)
# memory usage: 820.0+ bytes
# None

# %%
# Display summary statistics
print(df.describe())
# Out:
#        Source Column Name            Description/Comment
# count                  43                             43
# unique                 43                             41
# top        SUMMONS-NUMBER  GEOGRAPHICAL STREET CODE
# freq                    1                              3

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Source Column Name     0
# Description/Comment    0
# dtype: int64

# %%
# Get information about the DataFrame
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Source Column Name   43 non-null     object
#  1   Description/Comment  43 non-null     object
# dtypes: object(2)
# memory usage: 820.0+ bytes
# None

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Display the column names to verify
print(df.columns)

# Example 1: Histogram of a numeric column
# Since there isn't a numeric column, this example isn't applicable.

# Example 2: Bar chart of a categorical column
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Source Column Name')
plt.title('Counts of Source Column Name')
plt.xlabel('Source Column Name')
plt.ylabel('Count')
plt.show()

# Example 3: Line plot of two columns
# Since there aren't suitable date and value columns, this example isn't applicable.
# Out:
# Index(['Source Column Name', 'Description/Comment'], dtype='object')
